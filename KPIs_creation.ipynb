# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/Users/swaroopbasavarajmusti/Desktop/2023-03-07 3_38pm (1).csv')

# %%
df
# Out:
#                REPORT_WEEK  COUNTRY        CITY                  STORE_ID  \
# 0     2021-11-08T00:00:00Z  Germany      Berlin  607d595c6416362c3056a2a3
# 1     2021-09-27T00:00:00Z  Germany      Munich  60cb51b466aac7019f467202
# 2     2021-11-29T00:00:00Z  Germany      Berlin  60e5be8703c8cd48380f7d93
# 3     2021-04-05T00:00:00Z  Germany   Frankfurt  6044e83dc4f9db1a311a0c90
# 4     2022-03-07T00:00:00Z  Germany        Köln  603fd7a5f5958661fd5a96c0
# ...                    ...      ...         ...                       ...
# 7521  2023-01-23T00:00:00Z  Germany  Düsseldorf  6045fea095edb91ffe5cf3cd
# 7522  2023-01-02T00:00:00Z  Germany       Essen  60b3fb665789cd5cd5c4c7bd
# 7523  2023-02-13T00:00:00Z  Germany        Köln  6006c944a309ba6538d44c19
# 7524  2022-10-03T00:00:00Z  Germany      Berlin  61e06df709554a281b5c9bd4
# 7525  2022-09-26T00:00:00Z  Germany   Frankfurt  6092d9e2884d550a74d64a2c
#
#       TOTAL_ORDERS         GMV  CUSTOMER_PAID     GMV_EUR  CUSTOMER_PAID_EUR  \
# ...

# %%
sales_num = df.groupby(['CITY'])['TOTAL_ORDERS','GMV'].sum()
sales_num['GMV'] = sales_num['GMV'].astype(int)
# Out:
# /var/folders/67/njs_9h493jg413mvx8b246nr0000gp/T/ipykernel_98366/1831031446.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   sales_num = df.groupby(['CITY'])['TOTAL_ORDERS','GMV'].sum()

# %%
sales_num.sort_values(by = ['TOTAL_ORDERS'],ascending=False)
sales_num['AVG_OV'] = sales_num['GMV']/sales_num['TOTAL_ORDERS']
sales_num
# Out:
#                TOTAL_ORDERS        GMV     AVG_OV
# CITY
# Augsburg             110371    2808636  25.447228
# Berlin              4409997  114406510  25.942537
# Bochum                24033     522472  21.739774
# Bonn                 151238    3539771  23.405302
# Bremen               203206    4971849  24.467038
# Darmstadt             58176    1414161  24.308323
# Dortmund              78514    1596949  20.339672
# Dresden              160515    3882482  24.187658
# Düsseldorf           705305   17123849  24.278644
# Essen                126293    2904001  22.994156
# Frankfurt            643670   16474963  25.595356
# Fürth                 79702    2090654  26.230885
# Gelsenkirchen         44406     825868  18.598117
# Hamburg             1633167   40358918  24.712058
# Hanover              197212    5008471  25.396381
# Heidelberg            99327    2357883  23.738591
# Karlsruhe            167559    4190550  25.009400
# Köln                1078366   25770554  23.897781
# ...
